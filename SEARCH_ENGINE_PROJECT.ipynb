# %% [markdown]
# ### CS600 PROJECT  - SHREY TANNA

# %% [markdown]
# ### Function to process the html pages to extract words

# %%
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from collections import Counter
# nltk.download('stopwords')
import re
import os


def extract_words_from_html(path):
    with open(path, 'r', encoding='utf-8') as file:
        html_content = file.read()
    
    # Now we have the data from our HTML file that we have stored locally and we need to parse HTML content for our processing
    res = BeautifulSoup(html_content, 'html.parser')
    
    # Using beautiful soup we have extracted the text from our HTML file
    text = res.get_text()
    
    # We only need words that have alphabets from A-Z and a-z and in our data and ignore all the other symbols hence we tokenize the text into words
    words = re.findall(r'\b[A-Za-z]+\b', text)
    
    # We remove all the stop words from our data using NLTK's list of stop words
    stop_words = set(stopwords.words('english'))
    filtered_words = [word.lower() for word in words if word.lower() not in stop_words]
    
    # We can see the difference in number of words before and after removing the stop words 
    print("Number of words before removing the stop words:", len(words))
    print("Number of words after removing the stop words:", len(filtered_words))
    
    #To count the occurences of all the words, we create a Counter object and then convert it to a dictionary
    word_occurrences = Counter(filtered_words)
    word_occurrences = dict(word_occurrences)
    # word_occurrences
    return word_occurrences

# %% [markdown]
# ### Reading all the pages from local storage

# %%
files = [r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\PROJECT\Formula One - Wikipedia.html", r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\PROJECT\History of Formula One - Wikipedia.html",
        r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\PROJECT\Mercedes-Benz in Formula One - Wikipedia.html", r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\PROJECT\Red Bull Racing - Wikipedia.html",
        r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\PROJECT\2023 Formula One World Championship - Wikipedia.html", r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\PROJECT\Scuderia Ferrari - Wikipedia.html",
        r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\PROJECT\List of Formula One driver records - Wikipedia.html", r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\PROJECT\List of Formula One World Drivers' Champions - Wikipedia.html"]

words_in_pages = {}

for path in files:
    print(f"PROCESSING FILE: {os.path.basename(path)}")
    word_occurrences = extract_words_from_html(path)
    words_in_pages[os.path.basename(path)] = word_occurrences
    print('\n')
# Out:
# PROCESSING FILE: Formula One - Wikipedia.html
# Number of words before removing the stop words: 20484
# Number of words after removing the stop words: 13649
#
#
# PROCESSING FILE: History of Formula One - Wikipedia.html
# Number of words before removing the stop words: 14985
# Number of words after removing the stop words: 9119
#
#
# PROCESSING FILE: Mercedes-Benz in Formula One - Wikipedia.html
# Number of words before removing the stop words: 8625
# Number of words after removing the stop words: 6470
#
#
# PROCESSING FILE: Red Bull Racing - Wikipedia.html
# Number of words before removing the stop words: 13943
# Number of words after removing the stop words: 9660
#
#
# PROCESSING FILE: 2023 Formula One World Championship - Wikipedia.html
# Number of words before removing the stop words: 11945
# Number of words after removing the stop words: 8387
#
#
# PROCESSING FILE: Scuderia Ferrari - Wikipedia.html
# Number of words before removing the stop words: 7594
# Number of words after removing the stop words: 5401
#
#
# PROCESSING FILE: List of Formula One driver records - Wikipedia.html
# Number of words before removing the stop words: 11850
# Number of words after removing the stop words: 9978
#
#
# PROCESSING FILE: List of Formula One World Drivers' Champions - Wikipedia.html
# Number of words before removing the stop words: 3820
# Number of words after removing the stop words: 2809

# %%
class TNode:

    def __init__(self):
        self.children = {}
        self.flag = False
        self.DataFound = []
        
class Trie:
    def __init__(self):
        self.root = TNode()
    
    def insert(self, word, pages):
        curr = self.root
        
        for c in word:
            if c not in curr.children:
                curr.children[c] = TNode()
                
            curr = curr.children[c]
        curr.flag = True
        curr.DataFound.append(pages)
    
    def search(self,word):
        curr = self.root
        for c in word:
            if c not in curr.children:
#                 return 'Not Found 1'
                return """
                                    Not Found"""
            curr = curr.children[c]
        if curr.flag:
            return curr.DataFound, word
#         else:
#             return "Not Found 2"
        while True:
            try:
                option = int(input("Would you like the available suggestions: \n\n1: yes \n0: no\n\nChoice: "))
                if option == 1:
                    output = self.suggest(word)
                    #return(output)
                    print("\nPlease type in the word from the below suggestion list:\n\n",output)
                    print('\nSuggested successfully!!')
                    suggest_accepted = input("\nIf you want to search for any above sugestions please enter from the above given: \n\nNew Word: ").lower()
                    return (self.search(suggest_accepted))
                
                elif option == 0:
                    return 'Not Found 3'
                
                else:
                    print("\nPLEASE ENTER 0 OR 1\n")
            except ValueError:
                print("\nPLEASE ENTER 0 OR 1\n")


        
                    #THIS WOULD SORT OF BE LIKE AUTCOMPLETE WHERE IT WOULD ASK THE USER IF IT MEANT ANY OF THE FOLLOWING SUGGESTIONS OR NOT
        
    def suggest(self,prefix):
        suggestions = []
        curr = self.root
        
        for c in prefix:
            if c not in curr.children:
                return suggestions
            curr = curr.children[c]
        
        self.dfs(curr,prefix,suggestions)
        return suggestions
    
    def dfs(self,node, prefix, suggestions):
        if node.flag:
            suggestions.append(prefix)
        
        for c, ref_node in node.children.items():
            self.dfs(ref_node, prefix + c, suggestions)

# %%
t = Trie()
l = 0
for k in words_in_pages:
    for word in words_in_pages[k].keys():
        t.insert(word,k)

# %%
import pandas as pd
from tabulate import tabulate
# import warnings
# warnings.filterwarnings('ignore')



#Creating a txt file to store our output
txt_path = r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\PROJECT\output.txt"



#Before adding new data to our txt file we need to clear it by opening the file in 'write' format
with open(txt_path,'w') as file:
    file.write("")
    
  
research = 1
while research:
    word_to_search = input('\nEnter the word you want to search: \nWord: ').lower()
    search_result = t.search(word_to_search)
    df = pd.DataFrame(columns=['PAGES', 'OCCURENCES'])
    # search_result
    # print(len(search_result))
    if len(search_result) == 2:
        pages , word = search_result
        for page in pages:
            occurences = words_in_pages[page][word]
            res_df = pd.DataFrame({'PAGES': [page], 'OCCURENCES': [occurences]})
            #df = df.append({'PAGES' : page, 'OCCURENCES' : occurences}, ignore_index = True)
            df = pd.concat([df,res_df], ignore_index=True)
        df = df.sort_values(by=['OCCURENCES'], ascending=False)
#         print(df)
        
        
        #Converting the dataframe to a table
        data_table = tabulate(df, headers='keys', tablefmt='grid', showindex=False)
        print('\nResult:\n', data_table)
        
        #Saving the dataframe to txt file
#         txt_path = r"C:\Users\SHREY\OneDrive\Desktop\STEVENS SUBJECTS\CS 600 ADV ALGO\output.txt"
        with open(txt_path, 'a') as file:
            file.write(f"Search Results for: {word}\n\n")
            file.write(data_table + '\n\n' + '-'*100 + '\n\n')
        
        print("Data Saved")

        
        while True:  
            research = input("\n\n\t\t\tDo you want to keep searching?: \n\n\t\t\t1: yes\n\t\t\t0: no\n\n\t\t\tChoice: ")
            if research == '1' or research == '0':
                research = int(research)
                break
            else:
                print("\n\t\t\tInvalid input. Please enter 1 or 0. Retry.")
    else:
        print(search_result)
#         research = 0
        while True:  
            research = input("\n\n\t\t\tDo you want to keep searching?: \n\n\t\t\t1: yes\n\t\t\t0: no\n\n\t\t\tChoice: ")
            if research == '1' or research == '0':
                research = int(research)
                break
            else:
                print("\n\t\t\tInvalid input. Please enter 1 or 0. Retry.")

else:
    with open(txt_path, 'a') as file:
        file.write("\n\n\t\t\t\t\t\tThank you for using my search engine :)")
    print("\n\n\t\t\tThank you for using my search engine :)")
    print("\n\n\t\t\tSearch Results downloaded at defined location :)")
# Out:
# Enter the word you want to search:
# Word: hsm
#
#                                     Not Found
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 1
#
# Enter the word you want to search:
# Word: h
#
# Result:
#  +---------------------------------------------------------------+--------------+
# | PAGES                                                         |   OCCURENCES |
# +===============================================================+==============+
# | Formula One - Wikipedia.html                                  |            7 |
# +---------------------------------------------------------------+--------------+
# | Mercedes-Benz in Formula One - Wikipedia.html                 |            4 |
# +---------------------------------------------------------------+--------------+
# | Red Bull Racing - Wikipedia.html                              |            3 |
# +---------------------------------------------------------------+--------------+
# | Scuderia Ferrari - Wikipedia.html                             |            3 |
# +---------------------------------------------------------------+--------------+
# | History of Formula One - Wikipedia.html                       |            2 |
# +---------------------------------------------------------------+--------------+
# | 2023 Formula One World Championship - Wikipedia.html          |            1 |
# +---------------------------------------------------------------+--------------+
# | List of Formula One driver records - Wikipedia.html           |            1 |
# +---------------------------------------------------------------+--------------+
# | List of Formula One World Drivers' Champions - Wikipedia.html |            1 |
# +---------------------------------------------------------------+--------------+
# Data Saved
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: a
#
# 			Invalid input. Please enter 1 or 0. Retry.
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 1
#
# Enter the word you want to search:
# Word: a
# Would you like the available suggestions:
#
# 1: yes
# 0: no
#
# Choice: 1
#
# Please type in the word from the below suggestion list:
#
#  ['art', 'article', 'articleabout', 'articletalk', 'articles', 'artistic', 'artificial', 'arthur', 'around', 'aron', 'argue', 'argued', 'arguably', 'argentina', 'argentine', 'arm', 'armwrestling', 'armstrong', 'area', 'areas', 'arena', 'arenas', 'arabian', 'aramco', 'arao', 'arai', 'archive', 'archived', 'archives', 'archery', 'arca', 'arron', 'arrows', 'arrowsauto', 'arrival', 'arrivabene', 'arrive', 'arrived', 'arrangement', 'arzani', 'ariel', 'arno', 'arnold', 'arnoux', 'arden', 'arvid', 'across', 'acrobatic', 'account', 'according', 'accordingly', 'accompanied', 'accommodate', 'accepted', 'accelerate', 'acceleration', 'access', 'accessdate', 'accident', 'accidents', 'accurate', 'action', 'actions', 'active', 'activism', 'activities', 'activity', 'activated', 'acting', 'actual', 'actually', 'achieve', 'achieved', 'achieves', 'achiever', 'achievement', 'achievements', 'achieving', 'achille', 'achilles', 'acquisition', 'acquired', 'acquaintances', 'acknowledged', 'academy', 'acf', 'ace', 'acer', 'ad', 'add', 'addition', 'additions', 'additional', 'additionally', 'adding', 'added', 'adds', 'advertising', 'advent', 'adventure', 'advance', 'advances', 'advanced', 'advantage', 'advantages', 'advisor', 'administration', 'admitted', 'admits', 'adjust', 'adjustable', 'adjusted', 'adjustments', 'adjudge', 'adjacent', 'adapt', 'adam', 'adami', 'adac', 'adopt', 'adopted', 'adolf', 'adhesion', 'adhere', 'adelaide', 'adrian', 'af', 'africa', 'african', 'affect', 'affected', 'affiliation', 'affiliate', 'afford', 'afforded', 'affair', 'afm', 'aft', 'afternoon', 'afterwards', 'al', 'als', 'also', 'alfa', 'alfetta', 'alfettas', 'alfons', 'alfred', 'alfredo', 'aluminium', 'almost', 'almondo', 'although', 'alta', 'altered', 'alternative', 'alternate', 'altitude', 'alain', 'alan', 'alonso', 'alone', 'along', 'alongside', 'allow', 'allowing', 'allowed', 'allows', 'allowances', 'allocated', 'allocation', 'alloy', 'alloys', 'allan', 'allamericanracers', 'allard', 'allall', 'allinsport', 'allison', 'allisonwebsitewww', 'alliance', 'allied', 'alliot', 'allen', 'allegedly', 'alluded', 'albeit', 'albert', 'alberto', 'albon', 'alboreto', 'albion', 'always', 'already', 'alpha', 'alphatauri', 'alpine', 'alps', 'alessandro', 'alesi', 'alex', 'alexander', 'algarve', 'alguersuari', 'alcheva', 'alcohol', 'alive', 'align', 'aldo', 'alvis', 'au', 'aut', 'auto', 'automobile', 'automobiles', 'automobili', 'automotive', 'automatic', 'automation', 'automakersvehicle', 'autodrom', 'autodrome', 'autodromo', 'autocourse', 'autocross', 'autocentre', 'autocar', 'autocare', 'autosport', 'autoweek', 'autoblog', 'autohebdo', 'autoglass', 'autolease', 'autumn', 'authority', 'authorities', 'authors', 'aus', 'australia', 'australian', 'austria', 'austrian', 'austriaaustrian', 'austin', 'auscar', 'ausmotive', 'august', 'augusto', 'audi', 'audience', 'audiences', 'audits', 'audetto', 'aurelio', 'aurora', 'auxiliary', 'auf', 'aufrecht', 'association', 'associated', 'asserted', 'assemble', 'assembly', 'assigned', 'assist', 'assistance', 'aspirated', 'aspirations', 'aspects', 'asia', 'aside', 'aston', 'ascending', 'ascar', 'ascari', 'ascanelli', 'ask', 'asked', 'asking', 'ashes', 'asaki', 'annual', 'announce', 'announced', 'announces', 'announcement', 'announcing', 'annoyed', 'annoyingly', 'annotation', 'anniversary', 'another', 'anti', 'anticipated', 'anticlockwise', 'antitrust', 'antonelli', 'antonio', 'antonia', 'anteile', 'anthony', 'animal', 'andretti', 'andrew', 'andrews', 'andrea', 'andreas', 'andregulatory', 'anderstorp', 'andy', 'andsubsidiariesautomobile', 'andmarquescommercialvehicleproducerscurrent', 'andconsultanciescurrent', 'analyst', 'analysis', 'anxiety', 'ans', 'answer', 'answered', 'anglophone', 'angelis', 'angered', 'anyone', 'amount', 'amounts', 'amon', 'among', 'amorotti', 'amg', 'america', 'american', 'americas', 'amended', 'amedeo', 'ambrosio', 'ambitious', 'ambient', 'ambassador', 'ambassadors', 'amaury', 'amateur', 'amateurs', 'amazing', 'amassed', 'amd' ...
#
# Suggested successfully!!
#
# If you want to search for any above sugestions please enter from the above given:
#
# New Word: attitude
#
# Result:
#  +-----------------------------------------+--------------+
# | PAGES                                   |   OCCURENCES |
# +=========================================+==============+
# | History of Formula One - Wikipedia.html |            1 |
# +-----------------------------------------+--------------+
# Data Saved
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 1
#
# Enter the word you want to search:
# Word: shrey
#
#                                     Not Found
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 1
#
# Enter the word you want to search:
# Word: sh
# Would you like the available suggestions:
#
# 1: yes
# 0: no
#
# Choice: 1
#
# Please type in the word from the below suggestion list:
#
#  ['short', 'shortened', 'shorter', 'shortest', 'shortly', 'shootout', 'shooting', 'show', 'shown', 'showing', 'shows', 'showed', 'shoes', 'shotgun', 'shock', 'shovlin', 'shoichiro', 'shift', 'shifting', 'shirts', 'shine', 'shields', 'sheet', 'sheds', 'shell', 'shelvoke', 'shelved', 'shelby', 'sheffield', 'shea', 'share', 'shares', 'shared', 'sharealike', 'shareholding', 'shareholdingsand', 'shareholder', 'sharing', 'shake', 'shaken', 'shanghai', 'shannon', 'shades', 'shadow', 'shaft', 'shafts', 'shaped', 'shapes', 'shaping', 'shufu', 'shuhei', 'shutdown', 'shwartzman']
#
# Suggested successfully!!
#
# If you want to search for any above sugestions please enter from the above given:
#
# New Word: shelby
#
# Result:
#  +-----------------------------------+--------------+
# | PAGES                             |   OCCURENCES |
# +===================================+==============+
# | Scuderia Ferrari - Wikipedia.html |            1 |
# +-----------------------------------+--------------+
# Data Saved
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 1
#
# Enter the word you want to search:
# Word: 34
#
#                                     Not Found
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 1
#
# Enter the word you want to search:
# Word: 1
#
#                                     Not Found
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 1
#
# Enter the word you want to search:
# Word: 2
#
#                                     Not Found
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 3
#
# 			Invalid input. Please enter 1 or 0. Retry.
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 4
#
# 			Invalid input. Please enter 1 or 0. Retry.
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 5
#
# 			Invalid input. Please enter 1 or 0. Retry.
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice:
#
# 			Invalid input. Please enter 1 or 0. Retry.
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 6
#
# 			Invalid input. Please enter 1 or 0. Retry.
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 7
#
# 			Invalid input. Please enter 1 or 0. Retry.
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 8
#
# 			Invalid input. Please enter 1 or 0. Retry.
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 9
#
# 			Invalid input. Please enter 1 or 0. Retry.
#
#
# 			Do you want to keep searching?:
#
# 			1: yes
# 			0: no
#
# 			Choice: 0
#
#
# 			Thank you for using my search engine :)
#
#
# 			Search Results downloaded at defined location :)
